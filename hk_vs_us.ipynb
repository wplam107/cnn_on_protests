# %% [markdown]
# ## HK Protests vs. US Protests

# %%
# Standard
import numpy as np
import pandas as pd
import re
import pickle
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing and NLP
import spacy
from nltk.tokenize import sent_tokenize
from gensim.parsing.preprocessing import STOPWORDS
from gensim.utils import simple_preprocess

# Sentiment
from textblob import TextBlob

# %%
f = open('us_protests.p', 'rb')
df_us = pickle.load(f)
f.close()

# %%
f = open('hk_protests.p', 'rb')
df_hk = pickle.load(f)
f.close()

# %%
df_us['topic'] = 'US'
df_hk['topic'] = 'HK'

# %%
df = pd.concat([df_us, df_hk])

# %% [markdown]
# ## Cleaning Articles
# - Clean the body of escape characters and convert date strings to dates
# - Merge CNN articles on HK protests and US protests into 1 DataFrame
# - Remove investing and travel articles
# - 186 US protest (59%) and 129 HK protest (41%)

# %%
# Clean funtions
def string_to_date(s):
    if s == '':
        return None
    match = re.search(r'(?<=,\s)(.+$)', s).group(0)
    try:
        date = datetime.datetime.strptime(match, '%a %B %d, %Y')
    except:
        date = datatime.datetime.strptime(match, '%B %d, %Y')
    return date

def clean_body(s):
    try:
        match = re.search(r'(?<=\))(.*)', s).group(0)
    except:
        match = s
        
    match = match.replace('\'', '')
    match = re.sub(r'\(.*?\)', '', match)
    
    return match
    
def replace_words(s):
    s = s.replace('Gov.', 'governor')
    s = re.sub(r'U\.S\.', 'US', s)
    s = re.sub(r'U\.S\.A\.', 'US', s)
    s = re.sub(r'US', 'USA', s)
    s = re.sub(r'U\.K\.', 'UK', s)
    s = re.sub(r'Mr\.', 'MR', s)
    s = re.sub(r'Mrs\.', 'MRS', s)
    s = re.sub(r'Ms\.', 'MS', s)
    s = re.sub(r'\.\.\.', '', s)
    s = re.sub(r'U.S-China', 'US-China', s)
    s = s.replace('Co.', 'Co')
    
    return s

# %%
df['date'] = df['date'].map(string_to_date)
df['body'] = df['body'].map(clean_body)

# %%
df['body'] = np.where(df['body'] == '', None, df['body'])

# %%
df = df.loc[df['url'].map(lambda x: re.search(r'/money/', x)).isna()]
df = df.loc[df['url'].map(lambda x: re.search(r'/investing/', x)).isna()]
df = df.loc[df['url'].map(lambda x: re.search(r'/transport/', x)).isna()]

# %%
df.reset_index(inplace=True)
df.drop(columns='index', inplace=True)

# %%
print(df['topic'].value_counts())
print(df['topic'].value_counts(normalize=True))
# Out:
# US    186
# HK    129
# Name: topic, dtype: int64
# US    0.590476
# HK    0.409524
# Name: topic, dtype: float64

# %%
def preprocess_body(text, stopwords):
    simple_text = simple_preprocess(text)
    text_out = [ word for word in simple_text if word not in stopwords ]
    return text_out

def preprocess_sent(texts, stopwords):
    texts_out = []
    for text in texts:
        simple_text = simple_preprocess(text)
        no_stop = [ word for word in simple_text if word not in stopwords ]
        if no_stop != []:
            texts_out.append(no_stop)
    return texts_out

# %%
stopwords = STOPWORDS
nlp = spacy.load("en_core_web_sm")

# %%
df
# Out:
#                                               headline  \
# 0    New York passes a police reform bill package t...
# 1    3 recordings. 3 cries of 'I can't breathe.' 3 ...
# 2    The PGA Tour will leave the 8:46 tee time open...
# 3    Tennessee police chief tells officers they now...
# 4    Oakland police investigate state patrolmen's f...
# ..                                                 ...
# 310  5 things to know for June 12: Hong Kong, campa...
# 311
# 312  5 things to know for June 10: David Ortiz, Mex...
# 313          Fully occupied? Hong Kong's protest hotel
# 314                    China censors news on Sony hack
#
#                                                   body       date  \
# 0    New York legislators passed a package of bills... 2020-06-10
# 1    In the days since George Floyds cries that he ... 2020-06-10
# 2    The PGA Tour plans to honor George Floyd and t... 2020-06-10
# 3    Police officers in Chattanooga, Tennessee, now... 2020-06-10
# 4    Investigators are looking into the California ... 2020-06-10
# ..                                                 ...        ...
# 310  If youre into shutting down lemonade stands ru... 2019-06-12
# 311                                               None        NaT
# 312  Check out the building in Barcelona that final... 2019-06-10
# 313  The face of Hong Kongs chief executive covers ... 2015-01-29
# 314   search engine Baidu.com revealed a list of mo... 2014-12-24
#
#                                                    url topic
# 0    https://www.cnn.com/2020/06/10/us/new-york-pas...    US
# 1    https://www.cnn.com/2020/06/10/us/cant-breathe...    US
# 2    https://www.cnn.com/2020/06/10/us/pga-tour-tee...    US
# 3    https://www.cnn.com/2020/06/10/us/tn-police-of...    US
# 4    https://www.cnn.com/2020/06/10/us/oakland-poli...    US
# ..                                                 ...   ...
# 310  https://www.cnn.com/2019/06/12/us/five-things-...    HK
# 311  https://www.cnn.com/2019/06/11/asia/hong-kong-...    HK
# 312  https://www.cnn.com/2019/06/10/us/five-things-...    HK
# 313  https://www.cnn.com/2015/01/29/world/hong-kong...    HK
# 314  https://www.cnn.com/2014/12/24/world/asia/chin...    HK
#
# [315 rows x 5 columns]

# %%
doc = nlp(df['body'].iloc[314])

# %%
for token in doc:
    if token.text != ' ':
        print(
            token.text, '\n',
            token.pos_, '\n',
            token.tag_, '\n',
            token.is_stop, '\n',
        )
# Out:
# search
#  NOUN
#  NN
#  False
#
# engine
#  NOUN
#  NN
#  False
#
# Baidu.com
#  PROPN
#  NNP
#  False
#
# revealed
#  VERB
#  VBD
#  False
#
# a
#  DET
#  DT
#  True
#
# list
#  NOUN
#  NN
#  False
#
# of
#  ADP
#  IN
#  True
#
# mostly
#  ADV
#  RB
#  True
#
# positive
#  ADJ
#  JJ
#  False
#
# articles
#  NOUN
#  NNS
#  False
#
# about
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# DPRK
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# A
#  DET
#  DT
#  True
#
# Baidu
#  PROPN
#  NNP
#  False
#
# search
#  NOUN
#  NN
#  False
#
# for
#  ADP
#  IN
#  True
#
# "
#  PUNCT
#  ``
#  False
#
# North
#  PROPN
#  NNP
#  False
#
# Korea
#  PROPN
#  NNP
#  False
#
# hack
#  NOUN
#  NN
#  False
#
# "
#  PUNCT
#  ''
#  False
#
# in
#  ADP
#  IN
#  True
#
# English
#  PROPN
#  NNP
#  False
#
# revealed
#  VERB
#  VBD
#  False
#
# just
#  ADV
#  RB
#  True
#
# one
#  NUM
#  CD
#  True
#
# nearly
#  ADV
#  RB
#  False
#
# two
#  NUM
#  CD
#  True
#
# -
#  PUNCT
#  HYPH
#  False
#
# week
#  NOUN
#  NN
#  False
#
# -
#  PUNCT
#  HYPH
#  False
#
# old
#  ADJ
#  JJ
#  False
#
# article
#  NOUN
#  NN
#  False
#
# naming
#  VERB
#  VBG
#  False
#
# the
#  DET
#  DT
#  True
#
# DPRK
#  PROPN
#  NNP
#  False
#
# as
#  SCONJ
#  IN
#  True
#
# "
#  PUNCT
#  ``
#  False
#
# one
#  NUM
#  CD
#  True
#
# of
#  ADP
#  IN
#  True
#
# several
#  ADJ
#  JJ
#  True
#
# suspects
#  NOUN
#  NNS
#  False
#
# "
#  PUNCT
#  ''
#  False
#
# in
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# Sony
#  PROPN
#  NNP
#  False
#
# hacking
#  VERB
#  VBG
#  False
#
# investigation
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# An
#  DET
#  DT
#  True
#
# identical
#  ADJ
#  JJ
#  False
#
# search
#  NOUN
#  NN
#  False
#
# on
#  ADP
#  IN
#  True
#
# unrestricted
#  ADJ
#  JJ
#  False
#
# Google
#  PROPN
#  NNP
#  False
#
# on
#  ADP
#  IN
#  True
#
# Wednesday
#  PROPN
#  NNP
#  False
#
# found
#  VERB
#  VBD
#  False
#
# more
#  ADJ
#  JJR
#  True
#
# than
#  SCONJ
#  IN
#  True
#
# 36
#  NUM
#  CD
#  False
#
# million
#  NUM
#  CD
#  False
#
# articles
#  NOUN
#  NNS
#  False
#
# .
#  PUNCT
#  .
#  False
#
# When
#  ADV
#  WRB
#  True
#
# questioned
#  VERB
#  VBN
#  False
#
# by
#  ADP
#  IN
#  True
#
# foreign
#  ADJ
#  JJ
#  False
#
# reporters
#  NOUN
#  NNS
#  False
#
# on
#  ADP
#  IN
#  True
#
# Tuesday
#  PROPN
#  NNP
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# Chinas
#  PROPN
#  NNP
#  False
#
# Ministry
#  PROPN
#  NNP
#  False
#
# of
#  ADP
#  IN
#  True
#
# Foreign
#  PROPN
#  NNP
#  False
#
# Affairs
#  PROPN
#  NNPS
#  False
#
# spokeswoman
#  NOUN
#  NN
#  False
#
# Hua
#  PROPN
#  NNP
#  False
#
# Chunying
#  PROPN
#  NNP
#  False
#
# shied
#  VERB
#  VBD
#  False
#
# away
#  ADV
#  RB
#  False
#
# from
#  ADP
#  IN
#  True
#
# directly
#  ADV
#  RB
#  False
#
# addressing
#  VERB
#  VBG
#  False
#
# the
#  DET
#  DT
#  True
#
# issue
#  NOUN
#  NN
#  False
#
# on
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# Sony
#  PROPN
#  NNP
#  False
#
# hacking
#  VERB
#  VBG
#  False
#
# probe
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# "
#  PUNCT
#  ``
#  False
#
# We
#  PRON
#  PRP
#  True
#
# need
#  VERB
#  VBP
#  False
#
# sufficient
#  ADJ
#  JJ
#  False
#
# evidence
#  NOUN
#  NN
#  False
#
# before
#  ADP
#  IN
#  True
#
# drawing
#  VERB
#  VBG
#  False
#
# any
#  DET
#  DT
#  True
#
# conclusion
#  NOUN
#  NN
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# "
#  PUNCT
#  ''
#  False
#
# she
#  PRON
#  PRP
#  True
#
# said
#  VERB
#  VBD
#  False
#
# at
#  ADP
#  IN
#  True
#
# a
#  DET
#  DT
#  True
#
# news
#  NOUN
#  NN
#  False
#
# conference
#  NOUN
#  NN
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# adding
#  VERB
#  VBG
#  False
#
# that
#  SCONJ
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# United
#  PROPN
#  NNP
#  False
#
# States
#  PROPN
#  NNP
#  False
#
# and
#  CCONJ
#  CC
#  True
#
# North
#  PROPN
#  NNP
#  False
#
# Korea
#  PROPN
#  NNP
#  False
#
# should
#  VERB
#  MD
#  True
#
# communicate
#  VERB
#  VB
#  False
#
# .
#  PUNCT
#  .
#  False
#
# Of
#  ADV
#  RB
#  True
#
# course
#  ADV
#  RB
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# any
#  DET
#  DT
#  True
#
# substantive
#  ADJ
#  JJ
#  False
#
# communication
#  NOUN
#  NN
#  False
#
# is
#  AUX
#  VBZ
#  True
#
# unlikely
#  ADV
#  RB
#  False
#
# given
#  VERB
#  VBN
#  False
#
# the
#  DET
#  DT
#  True
#
# two
#  NUM
#  CD
#  True
#
# countries
#  NOUN
#  NNS
#  False
#
# have
#  AUX
#  VBP
#  True
#
# no
#  DET
#  DT
#  True
#
# diplomatic
#  ADJ
#  JJ
#  False
#
# ties
#  NOUN
#  NNS
#  False
#
# .
#  PUNCT
#  .
#  False
#
# The
#  DET
#  DT
#  True
#
# Great
#  PROPN
#  NNP
#  False
#
# Firewall
#  PROPN
#  NNP
#  False
#
# of
#  ADP
#  IN
#  True
#
# China
#  PROPN
#  NNP
#  False
#
# Censorship
#  PROPN
#  NNP
#  False
#
# is
#  AUX
#  VBZ
#  True
#
# the
#  DET
#  DT
#  True
#
# reality
#  NOUN
#  NN
#  False
#
# of
#  ADP
#  IN
#  True
#
# life
#  NOUN
#  NN
#  False
#
# behind
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# so
#  ADV
#  RB
#  True
#
# -
#  PUNCT
#  HYPH
#  False
#
# called
#  VERB
#  VBN
#  False
#
# Great
#  PROPN
#  NNP
#  False
#
# Firewall
#  PROPN
#  NNP
#  False
#
# of
#  ADP
#  IN
#  True
#
# China
#  PROPN
#  NNP
#  False
#
# .
#  PUNCT
#  .
#  False
#
# The
#  DET
#  DT
#  True
#
# Ministry
#  PROPN
#  NNP
#  False
#
# of
#  ADP
#  IN
#  True
#
# Public
#  PROPN
#  NNP
#  False
#
# Security
#  PROPN
#  NNP
#  False
#
# has
#  AUX
#  VBZ
#  True
#
# been
#  AUX
#  VBN
#  True
#
# heavily
#  ADV
#  RB
#  False
#
# censoring
#  VERB
#  VBG
#  False
#
# content
#  NOUN
#  NN
#  False
#
# for
#  ADP
#  IN
#  True
#
# more
#  ADJ
#  JJR
#  True
#
# than
#  SCONJ
#  IN
#  True
#
# a
#  DET
#  DT
#  True
#
# decade
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# The
#  DET
#  DT
#  True
#
# Chinese
#  ADJ
#  JJ
#  False
#
# government
#  NOUN
#  NN
#  False
#
# acknowledges
#  VERB
#  VBZ
#  False
#
# that
#  SCONJ
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# Internet
#  NOUN
#  NN
#  False
#
# is
#  AUX
#  VBZ
#  True
#
# a
#  DET
#  DT
#  True
#
# vital
#  ADJ
#  JJ
#  False
#
# tool
#  NOUN
#  NN
#  False
#
# to
#  PART
#  TO
#  True
#
# support
#  VERB
#  VB
#  False
#
# the
#  DET
#  DT
#  True
#
# countrys
#  NOUN
#  NN
#  False
#
# rapid
#  ADJ
#  JJ
#  False
#
# economic
#  ADJ
#  JJ
#  False
#
# growth
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# Chinese
#  ADJ
#  JJ
#  False
#
# e
#  PROPN
#  NNP
#  False
#
# -
#  PUNCT
#  HYPH
#  False
#
# commerce
#  NOUN
#  NN
#  False
#
# company
#  NOUN
#  NN
#  False
#
# Alibaba
#  PROPN
#  NNP
#  False
#
# transactions
#  NOUN
#  NNS
#  False
#
# totaled
#  VERB
#  VBD
#  False
#
# nearly
#  ADV
#  RB
#  False
#
# $
#  SYM
#  $
#  False
#
# 250
#  NUM
#  CD
#  False
#
# million
#  NUM
#  CD
#  False
#
# last
#  ADJ
#  JJ
#  True
#
# year
#  NOUN
#  NN
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# more
#  ADJ
#  JJR
#  True
#
# than
#  SCONJ
#  IN
#  True
#
# Amazon
#  PROPN
#  NNP
#  False
#
# and
#  CCONJ
#  CC
#  True
#
# eBay
#  PROPN
#  NNP
#  False
#
# combined
#  VERB
#  VBD
#  False
#
# .
#  PUNCT
#  .
#  False
#
# Alibabas
#  PROPN
#  NNP
#  False
#
# overall
#  ADJ
#  JJ
#  False
#
# revenue
#  NOUN
#  NN
#  False
#
# soared
#  VERB
#  VBD
#  False
#
# 54
#  NUM
#  CD
#  False
#
# %
#  NOUN
#  NN
#  False
#
# to
#  ADP
#  IN
#  True
#
# over
#  ADP
#  IN
#  True
#
# $
#  SYM
#  $
#  False
#
# 2.7
#  NUM
#  CD
#  False
#
# billion
#  NUM
#  CD
#  False
#
# in
#  ADP
#  IN
#  True
#
# 2014
#  NUM
#  CD
#  False
#
# .
#  PUNCT
#  .
#  False
#
# China
#  PROPN
#  NNP
#  False
#
# e
#  PROPN
#  NNP
#  False
#
# -
#  PUNCT
#  HYPH
#  False
#
# commerce
#  NOUN
#  NN
#  False
#
# transactions
#  NOUN
#  NNS
#  False
#
# are
#  AUX
#  VBP
#  True
#
# expected
#  VERB
#  VBN
#  False
#
# to
#  PART
#  TO
#  True
#
# skyrocket
#  VERB
#  VB
#  False
#
# to
#  ADP
#  IN
#  True
#
# more
#  ADJ
#  JJR
#  True
#
# than
#  SCONJ
#  IN
#  True
#
# $
#  SYM
#  $
#  False
#
# 700
#  NUM
#  CD
#  False
#
# billion
#  NUM
#  CD
#  False
#
# by
#  ADP
#  IN
#  True
#
# 2017
#  NUM
#  CD
#  False
#
# .
#  PUNCT
#  .
#  False
#
# But
#  CCONJ
#  CC
#  True
#
# with
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# Internet
#  NOUN
#  NN
#  False
#
# comes
#  VERB
#  VBZ
#  False
#
# the
#  DET
#  DT
#  True
#
# risk
#  NOUN
#  NN
#  False
#
# of
#  ADP
#  IN
#  True
#
# sharing
#  VERB
#  VBG
#  False
#
# information
#  NOUN
#  NN
#  False
#
# that
#  DET
#  WDT
#  True
#
# ,
#  PUNCT
#  ,
#  False
#
# the
#  DET
#  DT
#  True
#
# Chinese
#  ADJ
#  JJ
#  False
#
# government
#  NOUN
#  NN
#  False
#
# worries
#  NOUN
#  NNS
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# could
#  VERB
#  MD
#  True
#
# destabilize
#  VERB
#  VB
#  False
#
# the
#  DET
#  DT
#  True
#
# country
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# In
#  ADP
#  IN
#  True
#
# China
#  PROPN
#  NNP
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# any
#  DET
#  DT
#  True
#
# threat
#  NOUN
#  NN
#  False
#
# to
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# Communist
#  PROPN
#  NNP
#  False
#
# Partys
#  PROPN
#  NNP
#  False
#
# tightly
#  ADV
#  RB
#  False
#
# clenched
#  VERB
#  VBD
#  False
#
# grip
#  NOUN
#  NN
#  False
#
# must
#  VERB
#  MD
#  True
#
# be
#  AUX
#  VB
#  True
#
# controlled
#  VERB
#  VBN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# Its
#  DET
#  PRP$
#  True
#
# why
#  ADV
#  WRB
#  True
#
# you
#  PRON
#  PRP
#  True
#
# re
#  VERB
#  VBZ
#  True
#
# likely
#  ADJ
#  JJ
#  False
#
# to
#  PART
#  TO
#  True
#
# find
#  VERB
#  VB
#  False
#
# very
#  ADV
#  RB
#  True
#
# little
#  ADJ
#  JJ
#  False
#
# mention
#  NOUN
#  NN
#  False
#
# of
#  ADP
#  IN
#  True
#
# North
#  PROPN
#  NNP
#  False
#
# Koreas
#  PROPN
#  NNP
#  False
#
# bureau
#  NOUN
#  NN
#  False
#
# 121
#  NUM
#  CD
#  False
#
# in
#  ADP
#  IN
#  True
#
# this
#  DET
#  DT
#  True
#
# nation
#  NOUN
#  NN
#  False
#
# suspected
#  VERB
#  VBN
#  False
#
# of
#  ADP
#  IN
#  True
#
# having
#  VERB
#  VBG
#  False
#
# its
#  DET
#  PRP$
#  True
#
# own
#  ADJ
#  JJ
#  True
#
# shadowy
#  ADJ
#  JJ
#  False
#
# Peoples
#  PROPN
#  NNPS
#  False
#
# Liberation
#  PROPN
#  NNP
#  False
#
# Army
#  PROPN
#  NNP
#  False
#
# unit
#  NOUN
#  NN
#  False
#
# 61398
#  NUM
#  CD
#  False
#
# --
#  PUNCT
#  :
#  False
#
# believed
#  VERB
#  VBD
#  False
#
# to
#  PART
#  TO
#  True
#
# be
#  AUX
#  VB
#  True
#
# responsible
#  ADJ
#  JJ
#  False
#
# for
#  ADP
#  IN
#  True
#
# cyberespionage
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# Incidentally
#  ADV
#  RB
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# the
#  DET
#  DT
#  True
#
# Chinese
#  ADJ
#  JJ
#  False
#
# military
#  NOUN
#  NN
#  False
#
# has
#  AUX
#  VBZ
#  True
#
# also
#  ADV
#  RB
#  True
#
# denounced
#  VERB
#  VBN
#  False
#
# the
#  DET
#  DT
#  True
#
# United
#  PROPN
#  NNP
#  False
#
# States
#  PROPN
#  NNP
#  False
#
# for
#  ADP
#  IN
#  True
#
# having
#  VERB
#  VBG
#  False
#
# its
#  DET
#  PRP$
#  True
#
# own
#  ADJ
#  JJ
#  True
#
# massive
#  ADJ
#  JJ
#  False
#
# cyberspying
#  NOUN
#  NN
#  False
#
# program
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# As
#  SCONJ
#  IN
#  True
#
# all
#  DET
#  DT
#  True
#
# of
#  ADP
#  IN
#  True
#
# this
#  DET
#  DT
#  True
#
# continues
#  VERB
#  VBZ
#  False
#
# to
#  PART
#  TO
#  True
#
# unfold
#  VERB
#  VB
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# one
#  NUM
#  CD
#  True
#
# thing
#  NOUN
#  NN
#  False
#
# is
#  AUX
#  VBZ
#  True
#
# certain
#  ADJ
#  JJ
#  False
#
# :
#  PUNCT
#  :
#  False
#
# International
#  ADJ
#  JJ
#  False
#
# news
#  NOUN
#  NN
#  False
#
# organizations
#  NOUN
#  NNS
#  False
#
# such
#  ADJ
#  JJ
#  True
#
# as
#  SCONJ
#  IN
#  True
#
# CNN
#  PROPN
#  NNP
#  False
#
# will
#  VERB
#  MD
#  True
#
# continue
#  VERB
#  VB
#  False
#
# with
#  ADP
#  IN
#  True
#
# extensive
#  ADJ
#  JJ
#  False
#
# coverage
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False
#
# And
#  CCONJ
#  CC
#  True
#
# ,
#  PUNCT
#  ,
#  False
#
# thanks
#  NOUN
#  NNS
#  False
#
# to
#  ADP
#  IN
#  True
#
# heavy
#  ADJ
#  JJ
#  False
#
# -
#  PUNCT
#  HYPH
#  False
#
# handed
#  ADJ
#  JJ
#  False
#
# government
#  NOUN
#  NN
#  False
#
# censors
#  NOUN
#  NNS
#  False
#
# ,
#  PUNCT
#  ,
#  False
#
# most
#  ADJ
#  JJS
#  True
#
# citizens
#  NOUN
#  NNS
#  False
#
# of
#  ADP
#  IN
#  True
#
# China
#  PROPN
#  NNP
#  False
#
# will
#  VERB
#  MD
#  True
#
# continue
#  VERB
#  VB
#  False
#
# get
#  AUX
#  VB
#  True
#
# only
#  ADV
#  RB
#  True
#
# the
#  DET
#  DT
#  True
#
# news
#  NOUN
#  NN
#  False
#
# deemed
#  VERB
#  VBD
#  False
#
# appropriate
#  ADJ
#  JJ
#  False
#
# by
#  ADP
#  IN
#  True
#
# the
#  DET
#  DT
#  True
#
# government
#  NOUN
#  NN
#  False
#
# .
#  PUNCT
#  .
#  False

# %%
df['sentences'] = df['body'].map(sent_tokenize)

# %%
df['tokens'] = df['body'].map(lambda x: preprocess_body(x, stopwords))

# %%
df['sent_tokens'] = df['sentences'].map(lambda x: preprocess_sent(x, stopwords))

# %%
df['word_length'] = df['tokens'].map(len)
df['sent_length'] = df['sentences'].map(len)

# %%
df['sentences'].iloc[0]

# %%
doc = nlp(df['body'].iloc[0])

# %% [markdown]
# ## Early EDA
# - Classes and mean lengths:
#     - HK Articles - 94 (mean 365 words and 30 sentences)
#     - US Articles - 183 (mean 367 words and 35 sentences)
# - Dropped articles with word length > 1000 (6 articles, 2 HK and 3 US), all seem to be updates on older articles or long form

# %%
df = df.loc[df['word_length'] <= 1000]

# %%
print(df.groupby('topic')['word_length'].mean())
print(df.groupby('topic')['sent_length'].mean())
